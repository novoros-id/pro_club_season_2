# %%
from PIL import Image
from transformers import Blip2Processor, Blip2ForConditionalGeneration

# Загружаем процессор и модель BLIP-2 один раз
processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", device_map="auto")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# ...

# %%
from PIL import Image
from transformers import Blip2Processor, Blip2ForConditionalGeneration

# Загружаем процессор и модель BLIP-2 один раз
processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.

# %%
from google.colab import userdata
userdata.get('HF_TOKEN')
# Out:
# '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'

# %%
def describe_image(image_path, question):
    """
    Функция для получения описания изображения.

    :param image_path: Путь к изображению на диске
    :param question: Вопрос о содержимом изображения (по умолчанию "What is in the picture?")
    :return: Описание содержимого изображения
    """
    # Загружаем изображение и конвертируем его в RGB
    raw_image = Image.open(image_path).convert('RGB')

    # Обрабатываем изображение и вопрос, переводим на GPU
    inputs = processor(raw_image, question, return_tensors="pt").to("cuda")

    # Генерируем ответ
    out = model.generate(**inputs)

    # Декодируем и возвращаем ответ
    return processor.decode(out[0], skip_special_tokens=True).strip()

# Пример использования функции
image_path = '12345.png'  # Замените на путь к вашему изображению
question = 'what is shown in the picture'
description = describe_image(image_path, question)
print(description)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2048eaa7c450> in <cell line: 0>()
#      22 image_path = '12345.png'  # Замените на путь к вашему изображению
#      23 question = 'what is shown in the picture'
# ---> 24 description = describe_image(image_path, question)
#      25 print(description)
#
# <ipython-input-2-2048eaa7c450> in describe_image(image_path, question)
#      14
#      15     # Генерируем ответ
# ---> 16     out = model.generate(**inputs)
#      17
#      18     # Декодируем и возвращаем ответ
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
def describe_image(image_path, question):
    """
    Функция для получения описания изображения.

    :param image_path: Путь к изображению на диске
    :param question: Вопрос о содержимом изображения (по умолчанию "What is in the picture?")
    :return: Описание содержимого изображения
    """
    # Загружаем изображение и конвертируем его в RGB
    raw_image = Image.open(image_path).convert('RGB')

    # Обрабатываем изображение и вопрос, переводим на GPU
    inputs = processor(raw_image, question, return_tensors="pt").to("cuda")

    # Генерируем ответ
    out = model.generate(**inputs)

    # Декодируем и возвращаем ответ
    return processor.decode(out[0], skip_special_tokens=True).strip()

# Пример использования функции
image_path = '12345.png'  # Замените на путь к вашему изображению
question = 'what is shown in the picture'
description = describe_image(image_path, question)
print(description)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py:2347: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cuda, whereas the model is on meta. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('meta') before running `.generate()`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2048eaa7c450> in <cell line: 0>()
#      22 image_path = '12345.png'  # Замените на путь к вашему изображению
#      23 question = 'what is shown in the picture'
# ---> 24 description = describe_image(image_path, question)
#      25 print(description)
#
# <ipython-input-5-2048eaa7c450> in describe_image(image_path, question)
# ...

# %%
from PIL import Image
from transformers import Blip2Processor, Blip2ForConditionalGeneration

processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def describe_image(image_path, question):
    """
    Функция для получения описания изображения.

    :param image_path: Путь к изображению на диске
    :param question: Вопрос о содержимом изображения (по умолчанию "What is in the picture?")
    :return: Описание содержимого изображения
    """
    # Загружаем изображение и конвертируем его в RGB
    raw_image = Image.open(image_path).convert('RGB')

    # Обрабатываем изображение и вопрос, переводим на GPU
    inputs = processor(raw_image, question, return_tensors="pt").to("cuda")

    # Генерируем ответ
    out = model.generate(**inputs)

    # Декодируем и возвращаем ответ
    return processor.decode(out[0], skip_special_tokens=True).strip()

# Пример использования функции
image_path = '12345.png'  # Замените на путь к вашему изображению
question = 'what is shown in the picture'
description = describe_image(image_path, question)
print(description)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-2048eaa7c450> in <cell line: 0>()
#      22 image_path = '12345.png'  # Замените на путь к вашему изображению
#      23 question = 'what is shown in the picture'
# ---> 24 description = describe_image(image_path, question)
#      25 print(description)
#
# <ipython-input-7-2048eaa7c450> in describe_image(image_path, question)
#      14
#      15     # Генерируем ответ
# ---> 16     out = model.generate(**inputs)
#      17
#      18     # Декодируем и возвращаем ответ
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
import requests
from PIL import Image
from transformers import Blip2Processor, Blip2ForConditionalGeneration

processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", device_map="auto")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.

# %%
import requests
from PIL import Image
from transformers import Blip2Processor, Blip2ForConditionalGeneration

processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# ...

# %%
def describe_image(image_path, question):
    """
    Функция для получения описания изображения.

    :param image_path: Путь к изображению на диске
    :param question: Вопрос о содержимом изображения (по умолчанию "What is in the picture?")
    :return: Описание содержимого изображения
    """
    # Загружаем изображение и конвертируем его в RGB
    raw_image = Image.open(image_path).convert('RGB')

    # Обрабатываем изображение и вопрос, переводим на GPU
    inputs = processor(raw_image, question, return_tensors="pt").to("cuda")

    # Генерируем ответ
    out = model.generate(**inputs)

    # Декодируем и возвращаем ответ
    return processor.decode(out[0], skip_special_tokens=True).strip()

# Пример использования функции
image_path = '12345.png'  # Замените на путь к вашему изображению
question = 'what is shown in the picture'
description = describe_image(image_path, question)
print(description)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2048eaa7c450> in <cell line: 0>()
#      22 image_path = '12345.png'  # Замените на путь к вашему изображению
#      23 question = 'what is shown in the picture'
# ---> 24 description = describe_image(image_path, question)
#      25 print(description)
#
# <ipython-input-2-2048eaa7c450> in describe_image(image_path, question)
#       8     """
#       9     # Загружаем изображение и конвертируем его в RGB
# ---> 10     raw_image = Image.open(image_path).convert('RGB')
#      11
#      12     # Обрабатываем изображение и вопрос, переводим на GPU
#
# NameError: name 'Image' is not defined

# %%
from PIL import Image
from transformers import Blip2Processor, Blip2ForConditionalGeneration

# Загружаем процессор и модель BLIP-2 один раз
processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b", device_map="auto")
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# ...

# %%
def describe_image(image_path, question):
    """
    Функция для получения описания изображения.

    :param image_path: Путь к изображению на диске
    :param question: Вопрос о содержимом изображения (по умолчанию "What is in the picture?")
    :return: Описание содержимого изображения
    """
    # Загружаем изображение и конвертируем его в RGB
    raw_image = Image.open(image_path).convert('RGB')

    # Обрабатываем изображение и вопрос, переводим на GPU
    inputs = processor(raw_image, question, return_tensors="pt").to("cuda")

    # Генерируем ответ
    out = model.generate(**inputs)

    # Декодируем и возвращаем ответ
    return processor.decode(out[0], skip_special_tokens=True).strip()

# Пример использования функции
image_path = '12345.png'  # Замените на путь к вашему изображению
question = 'what is shown in the picture'
description = describe_image(image_path, question)
print(description)
# Out:
# what is shown in the picture is a man in a blue suit

# %%
pip install opencv-python

# %%
import cv2

# %%
def save_frame_at_time(video_path, time_str, output_image_path):
    hours, minutes, seconds = map(int, time_str.split(':'))
    total_seconds = hours * 3600 + minutes * 60 + seconds

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Не удалось открыть видеофайл")
        return

    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = frame_count / fps

    print(f"Общее количество кадров: {frame_count}")
    print(f"Длительность видео (в секундах): {duration}")

    if total_seconds > duration:
        print("Указанное время превышает длительность видео.")
        return

    cap.set(cv2.CAP_PROP_POS_MSEC, total_seconds * 1000)

    ret, frame = cap.read()

    if ret:
        cv2.imwrite(output_image_path, frame)
        print(f"Кадр сохранен как {output_image_path}")
    else:
        print("Не удалось извлечь кадр")
        print(f"Текущая позиция в миллисекундах: {cap.get(cv2.CAP_PROP_POS_MSEC)}")

    cap.release()

# Пример использования
video_file = '111.mp4'
time_to_capture = '00:03:00'
output_file = 'screenshot.png'

save_frame_at_time(video_file, time_to_capture, output_file)
# Out:
# Общее количество кадров: 5047
# Длительность видео (в секундах): 201.88
# Кадр сохранен как screenshot.png

# %%
def save_frame_at_time(video_path, time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    total_seconds = hours * 3600 + minutes * 60 + seconds

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Не удалось открыть видеофайл")
        return None

    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = frame_count / fps

    print(f"Общее количество кадров: {frame_count}")
    print(f"Длительность видео (в секундах): {duration}")

    if total_seconds > duration:
        print("Указанное время превышает длительность видео.")
        return None

    cap.set(cv2.CAP_PROP_POS_MSEC, total_seconds * 1000)

    ret, frame = cap.read()

    if ret:
        output_image_path = 'screenshot.png'
        cv2.imwrite(output_image_path, frame)
        print(f"Кадр сохранен как {output_image_path}")
        cap.release()
        return output_image_path
    else:
        print("Не удалось извлечь кадр")
        print(f"Текущая позиция в миллисекундах: {cap.get(cv2.CAP_PROP_POS_MSEC)}")
        cap.release()
        return None

def describe_image(image_path, question):
    """
    Функция для получения описания изображения.

    :param image_path: Путь к изображению на диске
    :param question: Вопрос о содержимом изображения (по умолчанию "What is in the picture?")
    :return: Описание содержимого изображения
    """
    # Загружаем изображение и конвертируем его в RGB
    raw_image = Image.open(image_path).convert('RGB')

    # Обрабатываем изображение и вопрос, переводим на GPU
    inputs = processor(raw_image, question, return_tensors="pt").to("cuda")

    # Генерируем ответ
    out = model.generate(**inputs)

    # Декодируем и возвращаем ответ
    return processor.decode(out[0], skip_special_tokens=True).strip()

def main():
    video_file = input("Введите имя видео файла (например, '12345.mp4'): ")
    time_to_capture = input("Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): ")

    # Сохраняем кадр из видео
    image_path = save_frame_at_time(video_file, time_to_capture)

    if image_path:
        question = 'what is shown in the picture'
        description = describe_image(image_path, question)
        print(f"Описание: {description}")

if __name__ == "__main__":
    main()
# Out:
# Введите имя видео файла (например, '12345.mp4'): 111.mp4
# Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): 00:00:49
# Общее количество кадров: 5047
# Длительность видео (в секундах): 201.88
# Кадр сохранен как screenshot.png
# Описание: what is shown in the picture is a woman in a bathtub

# %%
from PIL import Image
import requests

from transformers import CLIPProcessor, CLIPModel

model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")

url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=["a photo of a cat", "a photo of a dog"], images=image, return_tensors="pt", padding=True)

outputs = model(**inputs)
logits_per_image = outputs.logits_per_image # this is the image-text similarity score
probs = logits_per_image.softmax(dim=1) # we can take the softmax to get the label probabilities
# Out:
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
from transformers import ViltProcessor, ViltForQuestionAnswering
import requests
from PIL import Image

# prepare image + question
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
text = "How many cats are there?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# Predicted answer: 2

# %%
url = "http://images.cocodataset.org/val2017/000000039769.jpg"
image = Image.open(requests.get(url, stream=True).raw)
text = "what is shown in the picture?"

processor = ViltProcessor.from_pretrained("dandelin/vilt-b32-finetuned-vqa")
model = ViltForQuestionAnswering.from_pretrained("dandelin/vilt-b32-finetuned-vqa")

# prepare inputs
encoding = processor(image, text, return_tensors="pt")

# forward pass
outputs = model(**encoding)
logits = outputs.logits
idx = logits.argmax(-1).item()
print("Predicted answer:", model.config.id2label[idx])
# Out:
# Predicted answer: cat

# %%
import requests

import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForCausalLM


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model = AutoModelForCausalLM.from_pretrained("microsoft/Florence-2-large", torch_dtype=torch_dtype, trust_remote_code=True).to(device)
processor = AutoProcessor.from_pretrained("microsoft/Florence-2-large", trust_remote_code=True)

prompt = "<OD>"

url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/car.jpg?download=true"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

generated_ids = model.generate(
    input_ids=inputs["input_ids"],
    pixel_values=inputs["pixel_values"],
    max_new_tokens=4096,
    num_beams=3,
    do_sample=False
)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

parsed_answer = processor.post_process_generation(generated_text, task="<OD>", image_size=(image.width, image.height))

print(parsed_answer)
# Out:
# config.json:   0%|          | 0.00/2.44k [00:00<?, ?B/s]
# configuration_florence2.py:   0%|          | 0.00/15.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Florence-2-large:
# - configuration_florence2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_florence2.py:   0%|          | 0.00/127k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Florence-2-large:
# - modeling_florence2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# ...

# %%
prompt = "<OD>"

url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/car.jpg?download=true"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

generated_ids = model.generate(
    input_ids=inputs["input_ids"],
    pixel_values=inputs["pixel_values"],
    max_new_tokens=4096,
    num_beams=3,
    do_sample=False
)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

parsed_answer = processor.post_process_generation(generated_text, task="<OD>", image_size=(image.width, image.height))

print(parsed_answer)
# Out:
# {'<OD>': {'bboxes': [[33.599998474121094, 160.55999755859375, 596.7999877929688, 371.7599792480469], [271.67999267578125, 242.1599884033203, 302.3999938964844, 246.95999145507812]], 'labels': ['car', 'door handle']}}

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model = AutoModelForCausalLM.from_pretrained("microsoft/Florence-2-large", torch_dtype=torch_dtype, trust_remote_code=True).to(device)
processor = AutoProcessor.from_pretrained("microsoft/Florence-2-large", trust_remote_code=True)

prompt = "<OD>"

url = "12345.png"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

generated_ids = model.generate(
    input_ids=inputs["input_ids"],
    pixel_values=inputs["pixel_values"],
    max_new_tokens=4096,
    num_beams=3,
    do_sample=False
)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

parsed_answer = processor.post_process_generation(generated_text, task="<OD>", image_size=(image.width, image.height))

print(parsed_answer)
# Out:
# config.json:   0%|          | 0.00/2.44k [00:00<?, ?B/s]
# configuration_florence2.py:   0%|          | 0.00/15.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Florence-2-large:
# - configuration_florence2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_florence2.py:   0%|          | 0.00/127k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Florence-2-large:
# - modeling_florence2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# ...

# %%
prompt = "<MORE_DETAILED_CAPTION>"

url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/transformers/tasks/car.jpg?download=true"
#url = '12345.png'
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

generated_ids = model.generate(
    input_ids=inputs["input_ids"],
    pixel_values=inputs["pixel_values"],
    max_new_tokens=4096,
    num_beams=3,
    do_sample=False
)
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

parsed_answer = processor.post_process_generation(generated_text, task="<MORE_DETAILED_CAPTION>", image_size=(image.width, image.height))

print(parsed_answer)
# Out:
# {'<MORE_DETAILED_CAPTION>': 'The image shows a vintage Volkswagen Beetle car parked on a cobblestone street in front of a yellow building with two wooden doors. The car is painted in a bright turquoise color and has a white stripe running along the side. The doors are made of wood and have a rustic, weathered look. The building behind the car has a small window and a door handle. The sky is blue and there are trees in the background. The overall atmosphere of the image is peaceful and serene.'}

# %%
# Укажите путь к своему изображению
image_path = "12345.png"  # Замените этот путь на свой

# Открываем изображение
image = Image.open(image_path)

# Ваш текстовый запрос
prompt = "<MORE_DETAILED_CAPTION>"

# Подготовка входных данных для модели
inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

# Генерация текста
generated_ids = model.generate(
    input_ids=inputs["input_ids"],
    pixel_values=inputs["pixel_values"],
    max_new_tokens=4096,
    num_beams=3,
    do_sample=False
)

# Декодирование сгенерированного текста
generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

# Постобработка результата
parsed_answer = processor.post_process_generation(generated_text, task="<MORE_DETAILED_CAPTION>", image_size=(image.width, image.height))

# Вывод результата
print(parsed_answer)
# Out:
# {'<MORE_DETAILED_CAPTION>': 'The image shows a man in a blue suit standing in a room with a pool in the background. The man is bald and appears to be in his late twenties or early thirties. He is holding a small white object in his hand and is looking down at it with a slight smile on his face. In the background, there are several people in the room, including a woman in a pink dress and a man with a bald head. The room is decorated with colorful furniture and plants, and there is a pink couch and a table with a vase of flowers on it. The overall mood of the image is cheerful and playful.'}

# %%
def save_frame_at_time(video_path, time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    total_seconds = hours * 3600 + minutes * 60 + seconds

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Не удалось открыть видеофайл")
        return None

    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = frame_count / fps

    print(f"Общее количество кадров: {frame_count}")
    print(f"Длительность видео (в секундах): {duration}")

    if total_seconds > duration:
        print("Указанное время превышает длительность видео.")
        return None

    cap.set(cv2.CAP_PROP_POS_MSEC, total_seconds * 1000)

    ret, frame = cap.read()

    if ret:
        output_image_path = 'screenshot.png'
        cv2.imwrite(output_image_path, frame)
        print(f"Кадр сохранен как {output_image_path}")
        cap.release()
        return output_image_path
    else:
        print("Не удалось извлечь кадр")
        print(f"Текущая позиция в миллисекундах: {cap.get(cv2.CAP_PROP_POS_MSEC)}")
        cap.release()
        return None

def describe_image(image_path):

    image = Image.open(image_path)

    # Ваш текстовый запрос
    prompt = "<MORE_DETAILED_CAPTION>"

    # Подготовка входных данных для модели
    inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

    # Генерация текста
    generated_ids = model.generate(
        input_ids=inputs["input_ids"],
        pixel_values=inputs["pixel_values"],
        max_new_tokens=4096,
        num_beams=3,
        do_sample=False
    )

    # Декодирование сгенерированного текста
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

    # Постобработка результата
    parsed_answer = processor.post_process_generation(generated_text, task="<MORE_DETAILED_CAPTION>", image_size=(image.width, image.height))

    # Вывод результата
    return parsed_answer

def main():
    video_file = input("Введите имя видео файла (например, '12345.mp4'): ")
    time_to_capture = input("Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): ")

    # Сохраняем кадр из видео
    image_path = save_frame_at_time(video_file, time_to_capture)

    if image_path:
        question = 'what is shown in the picture'
        description = describe_image(image_path, question)
        print(f"Описание: {description}")

if __name__ == "__main__":
    main()
# Out:
# Введите имя видео файла (например, '12345.mp4'): 111.mp4
# Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): 00:01:23
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-558e79ec4f86> in <cell line: 0>()
#      77
#      78 if __name__ == "__main__":
# ---> 79     main()
#
# <ipython-input-19-558e79ec4f86> in main()
#      69
#      70     # Сохраняем кадр из видео
# ---> 71     image_path = save_frame_at_time(video_file, time_to_capture)
#      72
#      73     if image_path:
#
# <ipython-input-19-558e79ec4f86> in save_frame_at_time(video_path, time_str)
#       3     total_seconds = hours * 3600 + minutes * 60 + seconds
#       4
# ----> 5     cap = cv2.VideoCapture(video_path)
#       6
#       7     if not cap.isOpened():
#
# NameError: name 'cv2' is not defined

# %%
pip install opencv-python
import cv2
import requests

import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForCausalLM

def save_frame_at_time(video_path, time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    total_seconds = hours * 3600 + minutes * 60 + seconds

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Не удалось открыть видеофайл")
        return None

    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = frame_count / fps

    print(f"Общее количество кадров: {frame_count}")
    print(f"Длительность видео (в секундах): {duration}")

    if total_seconds > duration:
        print("Указанное время превышает длительность видео.")
        return None

    cap.set(cv2.CAP_PROP_POS_MSEC, total_seconds * 1000)

    ret, frame = cap.read()

    if ret:
        output_image_path = 'screenshot.png'
        cv2.imwrite(output_image_path, frame)
        print(f"Кадр сохранен как {output_image_path}")
        cap.release()
        return output_image_path
    else:
        print("Не удалось извлечь кадр")
        print(f"Текущая позиция в миллисекундах: {cap.get(cv2.CAP_PROP_POS_MSEC)}")
        cap.release()
        return None

def describe_image(image_path):

    image = Image.open(image_path)

    # Ваш текстовый запрос
    prompt = "<MORE_DETAILED_CAPTION>"

    # Подготовка входных данных для модели
    inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

    # Генерация текста
    generated_ids = model.generate(
        input_ids=inputs["input_ids"],
        pixel_values=inputs["pixel_values"],
        max_new_tokens=4096,
        num_beams=3,
        do_sample=False
    )

    # Декодирование сгенерированного текста
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

    # Постобработка результата
    parsed_answer = processor.post_process_generation(generated_text, task="<MORE_DETAILED_CAPTION>", image_size=(image.width, image.height))

    # Вывод результата
    return parsed_answer

def main():
    video_file = input("Введите имя видео файла (например, '12345.mp4'): ")
    time_to_capture = input("Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): ")

    # Сохраняем кадр из видео
    image_path = save_frame_at_time(video_file, time_to_capture)

    if image_path:
        question = 'what is shown in the picture'
        description = describe_image(image_path, question)
        print(f"Описание: {description}")

if __name__ == "__main__":
    main()
# Out:
#   File "<ipython-input-20-363e0edb7910>", line 1
#     pip install opencv-python
#         ^
# SyntaxError: invalid syntax

# %%
pip install opencv-python

# %%
import cv2
import requests

import torch
from PIL import Image
from transformers import AutoProcessor, AutoModelForCausalLM

def save_frame_at_time(video_path, time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    total_seconds = hours * 3600 + minutes * 60 + seconds

    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Не удалось открыть видеофайл")
        return None

    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    duration = frame_count / fps

    print(f"Общее количество кадров: {frame_count}")
    print(f"Длительность видео (в секундах): {duration}")

    if total_seconds > duration:
        print("Указанное время превышает длительность видео.")
        return None

    cap.set(cv2.CAP_PROP_POS_MSEC, total_seconds * 1000)

    ret, frame = cap.read()

    if ret:
        output_image_path = 'screenshot.png'
        cv2.imwrite(output_image_path, frame)
        print(f"Кадр сохранен как {output_image_path}")
        cap.release()
        return output_image_path
    else:
        print("Не удалось извлечь кадр")
        print(f"Текущая позиция в миллисекундах: {cap.get(cv2.CAP_PROP_POS_MSEC)}")
        cap.release()
        return None

def describe_image(image_path):

    image = Image.open(image_path)

    # Ваш текстовый запрос
    prompt = "<MORE_DETAILED_CAPTION>"

    # Подготовка входных данных для модели
    inputs = processor(text=prompt, images=image, return_tensors="pt").to(device, torch_dtype)

    # Генерация текста
    generated_ids = model.generate(
        input_ids=inputs["input_ids"],
        pixel_values=inputs["pixel_values"],
        max_new_tokens=4096,
        num_beams=3,
        do_sample=False
    )

    # Декодирование сгенерированного текста
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]

    # Постобработка результата
    parsed_answer = processor.post_process_generation(generated_text, task="<MORE_DETAILED_CAPTION>", image_size=(image.width, image.height))

    # Вывод результата
    return parsed_answer

def main():
    video_file = input("Введите имя видео файла (например, '12345.mp4'): ")
    time_to_capture = input("Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): ")

    # Сохраняем кадр из видео
    image_path = save_frame_at_time(video_file, time_to_capture)

    if image_path:
        question = 'what is shown in the picture'
        description = describe_image(image_path)
        print(f"Описание: {description}")

if __name__ == "__main__":
    main()
# Out:
# Введите имя видео файла (например, '12345.mp4'): 111.mp4
# Введите время в формате ЧЧ:ММ:СС (например, '00:00:05'): 00:00:48
# Общее количество кадров: 5047
# Длительность видео (в секундах): 201.88
# Кадр сохранен как screenshot.png
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cde89c8965f3> in <cell line: 0>()
#      84
#      85 if __name__ == "__main__":
# ---> 86     main()
#
# <ipython-input-1-cde89c8965f3> in main()
#      80     if image_path:
#      81         question = 'what is shown in the picture'
# ---> 82         description = describe_image(image_path)
#      83         print(f"Описание: {description}")
#      84
#
# <ipython-input-1-cde89c8965f3> in describe_image(image_path)
#      51
#      52     # Подготовка входных данных для модели
# ...
